# %% [markdown]
# # Wordprocessor usage example

# %%
import json
import sys
import csv
sys.path.insert(0, '..') # ensures that the package is imported from the parent directory, not the Python installation


import tinytroupe
from tinytroupe.openai_utils import force_api_type
from tinytroupe.factory import TinyPersonFactory
from tinytroupe.agent import TinyPerson, TinyToolUse
from tinytroupe.environment import TinyWorld
from tinytroupe import control
from tinytroupe.extraction import ResultsExtractor, ResultsReducer
from tinytroupe.enrichment import TinyEnricher
from tinytroupe.extraction import ArtifactExporter
from tinytroupe.tools import TinyWordProcessor
from tinytroupe.steering import TinyStory
import tinytroupe.utils as utils
from tinytroupe.examples import create_lisa_the_data_scientist, create_oscar_the_architect, create_marcos_the_physician
# Out:
# !!!!
# DISCLAIMER: TinyTroupe relies on Artificial Intelligence (AI) models to generate content.
# The AI models are not perfect and may produce inappropriate or inacurate results.
# For any serious or consequential use, please review the generated content before using it.
# !!!!
#
# Looking for default config on: c:\Users\pdasilva\OneDrive - Microsoft\Git repositories\tinytroupe-opensource\TinyTroupe\examples\..\tinytroupe\config.ini
# Found custom config on: c:\Users\pdasilva\OneDrive - Microsoft\Git repositories\tinytroupe-opensource\TinyTroupe\examples\config.ini
#
# =================================
# Current TinyTroupe configuration
# =================================
# [OpenAI]
# api_type = openai
# azure_api_version = 2024-08-01-preview
# model = gpt-4o-mini
# max_tokens = 4000
# temperature = 1.5
# freq_penalty = 0.3
# presence_penalty = 0.0
# timeout = 60
# max_attempts = 5
# waiting_time = 2
# exponential_backoff_factor = 5
# embedding_model = text-embedding-3-small
# cache_api_calls = False
# cache_file_name = openai_api_cache.pickle
# max_content_display_length = 1024
# azure_embedding_model_api_version = 2023-05-15
#
# [Simulation]
# rai_harmful_content_prevention = True
# rai_copyright_infringement_prevention = True
#
# [Logging]
# loglevel = ERROR

# %%
data_export_folder = "../data/extractions/wordprocessor"

# %%
exporter = ArtifactExporter(base_output_folder=data_export_folder)
enricher = TinyEnricher()
tooluse_faculty = TinyToolUse(tools=[TinyWordProcessor(exporter=exporter, enricher=enricher)])

# %%
lisa = create_lisa_the_data_scientist()

# %%
lisa.add_mental_faculties([tooluse_faculty])
# Out:
# TinyPerson(name='Lisa')

# %%
lisa.listen_and_act("You have just been fired and need to find a new job. You decide to think about what you want in life and then write a resume. Make it very detailed.")
# Out:
# USER --> Lisa: [CONVERSATION]
#           > You have just been fired and need to find a new job. You decide to think about what you
#           > want in life and then write a resume. Make it very detailed.
# Lisa acts: [THINK]
#           > I need to reflect on what I want in my career and life after being fired. I should
#           > consider my skills, interests, and what kind of job would make me happy. I also need to
#           > think about how to present myself effectively in a resume.
# Lisa acts: [THINK]
#           > I need to identify my key skills and experiences that I want to highlight in my resume.
#           > I should also consider the types of companies and roles that align with my interests in
#           > data science and machine learning.
# Lisa acts: [WRITE_DOCUMENT]
#           > {   "title": "Resume of Lisa",   "content": "# Lisa   ## Contact Information   - Email:
#           > lisa@example.com   - Phone: (123) 456-7890    ## Summary   Data Scientist with over 5
#           > years of experience in analyzing user behavior and feedback data to improve search
#           > results. Proficient in Python and machine learning tools, with a strong focus on natural
#           > language processing and user experience.    ## Skills   - Proficient in Python, SQL, and
#           > data analysis tools (pandas, scikit-learn, TensorFlow)   - Experience with Azure ML and
#           > Power BI   - Strong analytical and problem-solving skills   - Excellent communication
#           > and teamwork abilities    ## Professional Experience   ### Microsoft - Data Scientist
#           > (M365 Search Team)   - Analyzed user behavior data to enhance search relevance.   -
#           > Built and tested machine learning models for various search scenarios.   - Collaborated
#           > with cross-functional teams to communicate findings and recommendations.    ### Previous
#           > Company - Data Analyst   - Conducted data analysis to support busine (...)
# 2024-12-11 19:30:07,465 - tinytroupe - ERROR - Error parsing JSON content: Invalid control character at: line 3 column 21 (char 51). Original content: {
#   "title": "Resume of Lisa",
#   "content": "# Lisa
#   ## Contact Information
#   - Email: lisa@example.com
#   - Phone: (123) 456-7890
#
#   ## Summary
#   Data Scientist with over 5 years of experience in analyzing user behavior and feedback data to improve search results. Proficient in Python and machine learning tools, with a strong focus on natural language processing and user experience.
#
#   ## Skills
#   - Proficient in Python, SQL, and data analysis tools (pandas, scikit-learn, TensorFlow)
#   - Experience with Azure ML and Power BI
#   - Strong analytical and problem-solving skills
#   - Excellent communication and teamwork abilities
#
#   ## Professional Experience
#   ### Microsoft - Data Scientist (M365 Search Team)
#   - Analyzed user behavior data to enhance search relevance.
#   - Built and tested machine learning models for various search scenarios.
#   - Collaborated with cross-functional teams to communicate findings and recommendations.
#
#   ### Previous Company - Data Analyst
#   - Conducted data analysis to support business decisions.
#   - Developed dashboards using Power BI for visualizing key metrics.
#
#   ## Education
#   - Bachelor’s Degree in Computer Science from University of Toronto.
#
#   ## Interests
#   - Artificial intelligence, cooking, playing the piano, watching movies.",
#   "author": "Lisa"
# }
# Lisa acts: [DONE]

# %%
lisa.listen_and_act("What did I just told you?")
# Out:
# USER --> Lisa: [CONVERSATION]
#           > What did I just told you?
# Lisa acts: [THINK]
#           > I need to recall what I just wrote in my resume and summarize it for the person asking.
#           > I should mention my skills, experience, and what I'm looking for in a new job.
# Lisa acts: [TALK]
#           > I just wrote a detailed resume highlighting my skills as a Data Scientist, my experience
#           > at Microsoft, and my proficiency in Python and machine learning tools. I'm looking for a
#           > new job that aligns with my interests in AI and user experience.
# Lisa acts: [DONE]
